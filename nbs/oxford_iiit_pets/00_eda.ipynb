# %%
from datasets import load_dataset

dataset = load_dataset("timm/oxford-iiit-pet")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label', 'image_id', 'label_cat_dog'],
#         num_rows: 3680
#     })
#     test: Dataset({
#         features: ['image', 'label', 'image_id', 'label_cat_dog'],
#         num_rows: 3669
#     })
# })

# %% [markdown]
# ## Save the dataset locally

# %%
from pathlib import Path
from loguru import logger
from datasets import DatasetDict
from PIL import Image

SAVE_DIR = Path("data/oxford-iiit-pet")
NUM_PROC = 8  
CLASS_NAMES = dataset['train'].features['label'].names

def save_image(example, idx):
    """Save a dataset image to disk with error handling and add label name.
    
    Args:
        example (dict): Dataset example containing 'image' and 'label'
        idx (int): Index of the example
        
    Returns:
        dict: Dictionary containing the saved filepath and label_name
    """
    try:
        image = example['image']
        label_id = example.get('label')  # Get label if it exists (won't exist for unlabeled)
        
        # Convert RGBA to RGB if necessary
        if image.mode == 'RGBA':
            # Create a white background
            background = Image.new('RGB', image.size, (255, 255, 255))
            # Paste the image using alpha channel as mask
            background.paste(image, mask=image.split()[3])
            image = background
        
        # Get label name if label exists
        label_name = CLASS_NAMES[label_id] if label_id is not None else None
        
        # Create directory structure
        label_dir = SAVE_DIR / str(label_id if label_id is not None else 'unlabeled')
        label_dir.mkdir(parents=True, exist_ok=True)
        
        # Create filename with label subdirectory
        filepath = label_dir / f"{idx:05d}.jpg"
        
        # Save with quality optimization
        image.save(filepath, "JPEG", quality=95, optimize=True)
        
        return {
            "filepath": str(filepath),
            "label_name": label_name
        }
    
    except Exception as e:
        logger.error(f"Error saving image {idx}: {str(e)}")
        return {
            "filepath": None,
            "label_name": None
        }

active_learning_dataset = DatasetDict()

active_learning_dataset['evaluation'] = dataset['test'].map(
    save_image,
    with_indices=True,
    num_proc=NUM_PROC,
    desc="Saving evaluation images",
    remove_columns="label"
)

active_learning_dataset['unlabeled'] = dataset['train'].map(
    save_image,
    with_indices=True,
    num_proc=NUM_PROC,
    desc="Saving unlabeled images",
    remove_columns="label"
)
# Out:
# Parameter 'function'=<function save_image at 0x7e3ee737eac0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Saving evaluation images (num_proc=8):   0%|          | 0/3669 [00:00<?, ? examples/s]
# Saving unlabeled images (num_proc=8):   0%|          | 0/3680 [00:00<?, ? examples/s]

# %%
active_learning_dataset
# Out:
# DatasetDict({
#     evaluation: Dataset({
#         features: ['image', 'image_id', 'label_cat_dog', 'filepath', 'label_name'],
#         num_rows: 3669
#     })
#     unlabeled: Dataset({
#         features: ['image', 'image_id', 'label_cat_dog', 'filepath', 'label_name'],
#         num_rows: 3680
#     })
# })

# %% [markdown]
# ## Make Initial Samples

# %%
import numpy as np

unique_labels = active_learning_dataset["unlabeled"].unique("label_name")
samples = []
n_samples_per_class = 10

for label in unique_labels:
    label_indices = np.where(np.array(active_learning_dataset["unlabeled"]["label_name"]) == label)[0]
    # Sample 10 random indices without replacement
    random_indices = np.random.choice(
        label_indices, size=n_samples_per_class, replace=False
    )
    samples.extend(random_indices)

initial_samples = active_learning_dataset["unlabeled"].select(samples)

# Verify the result (should show 100 rows total, 10 per class)
print(f"Total samples: {len(initial_samples)}")
print("\nSamples per class:")
print(initial_samples.select_columns(["label_name"]).to_pandas().value_counts())
# Out:
# Total samples: 370
#
# Samples per class:
# label_name
# abyssinian                    10
# american_bulldog              10
# american_pit_bull_terrier     10
# basset_hound                  10
# beagle                        10
# bengal                        10
# birman                        10
# bombay                        10
# boxer                         10
# british_shorthair             10
# chihuahua                     10
# egyptian_mau                  10
# english_cocker_spaniel        10
# english_setter                10
# german_shorthaired            10
# great_pyrenees                10
# havanese                      10
# japanese_chin                 10
# keeshond                      10
# leonberger                    10
# maine_coon                    10
# miniature_pinscher            10
# newfoundland                  10
# persian                       10
# pomeranian                    10
# pug                           10
# ragdoll                       10
# russian_blue                  10
# saint_bernard                 10
# samoyed                       10
# scottish_terrier              10
# shiba_inu                     10
# siamese                       10
# sphynx                        10
# staffordshire_bull_terrier    10
# wheaten_terrier               10
# yorkshire_terrier             10
# Name: count, dtype: int64

# %%
initial_samples
# Out:
# Dataset({
#     features: ['image', 'image_id', 'label_cat_dog', 'filepath', 'label_name'],
#     num_rows: 370
# })

# %%
initial_samples[1]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>,
#  'image_id': 'Maine_Coon_104',
#  'label_cat_dog': 0,
#  'filepath': 'data/oxford-iiit-pet/20/00546.jpg',
#  'label_name': 'maine_coon'}

# %%
initial_samples = initial_samples.remove_columns(["image", "image_id", "label_name"])
df = initial_samples.to_pandas()
df = df.rename(columns={"label_cat_dog": "label"})
df["label"] = df["label"].apply(lambda x: "cat" if x == 0 else "dog")
df
# Out:
#     label                           filepath
# 0     cat  data/oxford-iiit-pet/20/00624.jpg
# 1     cat  data/oxford-iiit-pet/20/00546.jpg
# 2     cat  data/oxford-iiit-pet/20/02051.jpg
# 3     cat  data/oxford-iiit-pet/20/00816.jpg
# 4     cat  data/oxford-iiit-pet/20/02624.jpg
# ..    ...                                ...
# 365   cat   data/oxford-iiit-pet/7/02456.jpg
# 366   cat   data/oxford-iiit-pet/7/01600.jpg
# 367   cat   data/oxford-iiit-pet/7/01758.jpg
# 368   cat   data/oxford-iiit-pet/7/01961.jpg
# 369   cat   data/oxford-iiit-pet/7/03518.jpg
#
# [370 rows x 2 columns]

# %%
df.to_parquet("data/oxford-iiit-pet/initial_samples.parquet")

# %% [markdown]
# ## Make Evaluation Split

# %%
active_learning_dataset["evaluation"][0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334>,
#  'image_id': 'newfoundland_31',
#  'label_cat_dog': 1,
#  'filepath': 'data/oxford-iiit-pet/22/00000.jpg',
#  'label_name': 'newfoundland'}

# %%
eval_samples = active_learning_dataset["evaluation"].remove_columns(["image", "image_id", "label_name"])
eval_samples = eval_samples.rename_column("label_cat_dog", "label")
eval_samples
# Out:
# Dataset({
#     features: ['label', 'filepath'],
#     num_rows: 3669
# })

# %%
df = eval_samples.to_pandas()
df["label"] = df["label"].apply(lambda x: "cat" if x == 0 else "dog")
df
# Out:
#      label                           filepath
# 0      dog  data/oxford-iiit-pet/22/00000.jpg
# 1      dog  data/oxford-iiit-pet/25/00001.jpg
# 2      dog   data/oxford-iiit-pet/1/00002.jpg
# 3      dog  data/oxford-iiit-pet/15/00003.jpg
# 4      dog  data/oxford-iiit-pet/16/00004.jpg
# ...    ...                                ...
# 3664   dog  data/oxford-iiit-pet/10/03664.jpg
# 3665   dog  data/oxford-iiit-pet/17/03665.jpg
# 3666   dog  data/oxford-iiit-pet/28/03666.jpg
# 3667   dog  data/oxford-iiit-pet/21/03667.jpg
# 3668   dog  data/oxford-iiit-pet/10/03668.jpg
#
# [3669 rows x 2 columns]

# %%
df.to_parquet("data/oxford-iiit-pet/evaluation_samples.parquet")

# %% [markdown]
# ## Make Unlabeled Split

# %%
unlabeled_samples = active_learning_dataset["unlabeled"].remove_columns(["image", "image_id", "label_name"])
unlabeled_samples = unlabeled_samples.rename_column("label_cat_dog", "label")
df = unlabeled_samples.to_pandas()
df["label"] = df["label"].apply(lambda x: "cat" if x == 0 else "dog")
df
# Out:
#      label                           filepath
# 0      cat  data/oxford-iiit-pet/20/00000.jpg
# 1      dog   data/oxford-iiit-pet/1/00001.jpg
# 2      dog  data/oxford-iiit-pet/18/00002.jpg
# 3      dog  data/oxford-iiit-pet/16/00003.jpg
# 4      dog  data/oxford-iiit-pet/14/00004.jpg
# ...    ...                                ...
# 3675   dog  data/oxford-iiit-pet/14/03675.jpg
# 3676   cat  data/oxford-iiit-pet/26/03676.jpg
# 3677   dog   data/oxford-iiit-pet/1/03677.jpg
# 3678   dog  data/oxford-iiit-pet/35/03678.jpg
# 3679   dog  data/oxford-iiit-pet/17/03679.jpg
#
# [3680 rows x 2 columns]

# %% [markdown]
# Remove the initial samples from the unlabeled samples

# %%
initial_filepaths = set(initial_samples['filepath'])
initial_filepaths
# Out:
# {'data/oxford-iiit-pet/0/00292.jpg',
#  'data/oxford-iiit-pet/0/01161.jpg',
#  'data/oxford-iiit-pet/0/01284.jpg',
#  'data/oxford-iiit-pet/0/01630.jpg',
#  'data/oxford-iiit-pet/0/01790.jpg',
#  'data/oxford-iiit-pet/0/02063.jpg',
#  'data/oxford-iiit-pet/0/02176.jpg',
#  'data/oxford-iiit-pet/0/02488.jpg',
#  'data/oxford-iiit-pet/0/02490.jpg',
#  'data/oxford-iiit-pet/0/03205.jpg',
#  'data/oxford-iiit-pet/1/00160.jpg',
#  'data/oxford-iiit-pet/1/00630.jpg',
#  'data/oxford-iiit-pet/1/01141.jpg',
#  'data/oxford-iiit-pet/1/01311.jpg',
#  'data/oxford-iiit-pet/1/01451.jpg',
#  'data/oxford-iiit-pet/1/02323.jpg',
#  'data/oxford-iiit-pet/1/02403.jpg',
#  'data/oxford-iiit-pet/1/02622.jpg',
#  'data/oxford-iiit-pet/1/02627.jpg',
#  'data/oxford-iiit-pet/1/02847.jpg',
#  'data/oxford-iiit-pet/10/00028.jpg',
#  'data/oxford-iiit-pet/10/00106.jpg',
#  'data/oxford-iiit-pet/10/00174.jpg',
#  'data/oxford-iiit-pet/10/01066.jpg',
#  'data/oxford-iiit-pet/10/01407.jpg',
#  'data/oxford-iiit-pet/10/01500.jpg',
#  'data/oxford-iiit-pet/10/02239.jpg',
#  'data/oxford-iiit-pet/10/02372.jpg',
#  'data/oxford-iiit-pet/10/03549.jpg',
#  'data/oxford-iiit-pet/10/03602.jpg',
#  'data/oxford-iiit-pet/11/00513.jpg',
#  'data/oxford-iiit-pet/11/00570.jpg',
#  'data/oxford-iiit-pet/11/00663.jpg',
#  'data/oxford-iiit-pet/11/00991.jpg',
#  'data/oxford-iiit-pet/11/01068.jpg',
#  'data/oxford-iiit-pet/11/01547.jpg',
#  'data/oxford-iiit-pet/11/02213.jpg',
#  'data/oxford-iiit-pet/11/02298.jpg',
#  'data/oxford-iiit-pet/11/02827.jpg',
#  'data/oxford-iiit-pet/11/03352.jpg',
#  'data/oxford-iiit-pet/12/00090.jpg',
#  'data/oxford-iiit-pet/12/00419.jpg',
#  'data/oxford-iiit-pet/12/00531.jpg',
#  'data/oxford-iiit-pet/12/00834.jpg',
#  'data/oxford-iiit-pet/12/01325.jpg',
#  'data/oxford-iiit-pet/12/01718.jpg',
#  'data/oxford-iiit-pet/12/01732.jpg',
#  'data/oxford-iiit-pet/12/02133.jpg',
#  'data/oxford-iiit-pet/12/02422.jpg',
#  'data/oxford-iiit-pet/12/02846.jpg',
#  'data/oxford-iiit-pet/13/00351.jpg',
#  'data/oxford-iiit-pet/13/00889.jpg',
#  'data/oxford-iiit-pet/13/01651.jpg',
#  'data/oxford-iiit-pet/13/01714.jpg',
#  'data/oxford-iiit-pet/13/01754.jpg',
#  'data/oxford-iiit-pet/13/01853.jpg',
#  'data/oxford-iiit-pet/13/02167.jpg',
#  'data/oxford-iiit-pet/13/02706.jpg',
#  'data/oxford-iiit-pet/13/03344.jpg',
#  'data/oxford-iiit-pet/13/03627.jpg',
#  'data/oxford-iiit-pet/14/00004.jpg',
#  'data/oxford-iiit-pet/14/00116.jpg',
#  'data/oxford-iiit-pet/14/00623.jpg',
#  'data/oxford-iiit-pet/14/01035.jpg',
#  'data/oxford-iiit-pet/14/01267.jpg',
#  'data/oxford-iiit-pet/14/02199.jpg',
#  'data/oxford-iiit-pet/14/02578.jpg',
#  'data/oxford-iiit-pet/14/02595.jpg',
#  'data/oxford-iiit-pet/14/02909.jpg',
#  'data/oxford-iiit-pet/14/03067.jpg',
#  'data/oxford-iiit-pet/15/00903.jpg',
#  'data/oxford-iiit-pet/15/01987.jpg',
#  'data/oxford-iiit-pet/15/02115.jpg',
#  'data/oxford-iiit-pet/15/02889.jpg',
#  'data/oxford-iiit-pet/15/03284.jpg',
#  'data/oxford-iiit-pet/15/03299.jpg',
#  'data/oxford-iiit-pet/15/03336.jpg',
#  'data/oxford-iiit-pet/15/03479.jpg',
#  'data/oxford-iiit-pet/15/03563.jpg',
#  'data/oxford-iiit-pet/15/03600.jpg',
#  'data/oxford-iiit-pet/16/00003.jpg',
#  'data/oxford-iiit-pet/16/00053.jpg',
#  'data/oxford-iiit-pet/16/00741.jpg',
#  'data/oxford-iiit-pet/16/00878.jpg',
#  'data/oxford-iiit-pet/16/00910.jpg',
#  'data/oxford-iiit-pet/16/01023.jpg',
#  'data/oxford-iiit-pet/16/01479.jpg',
#  'data/oxford-iiit-pet/16/01836.jpg',
#  'data/oxford-iiit-pet/16/02605.jpg',
#  'data/oxford-iiit-pet/16/02902.jpg',
#  'data/oxford-iiit-pet/17/00032.jpg',
#  'data/oxford-iiit-pet/17/01042.jpg',
#  'data/oxford-iiit-pet/17/01685.jpg',
#  'data/oxford-iiit-pet/17/02242.jpg',
#  'data/oxford-iiit-pet/17/02690.jpg',
#  'data/oxford-iiit-pet/17/02941.jpg',
#  'data/oxford-iiit-pet/17/02967.jpg',
#  'data/oxford-iiit-pet/17/03125.jpg',
#  'data/oxford-iiit-pet/17/03267.jpg',
#  'data/oxford-iiit-pet/17/03664.jpg',
#  'data/oxford-iiit-pet/18/00043.jpg',
#  'data/oxford-iiit-pet/18/00097.jpg',
#  'data/oxford-iiit-pet/18/00272.jpg',
#  'data/oxford-iiit-pet/18/01712.jpg',
#  'data/oxford-iiit-pet/18/02684.jpg',
#  'data/oxford-iiit-pet/18/02702.jpg',
#  'data/oxford-iiit-pet/18/02743.jpg',
#  'data/oxford-iiit-pet/18/03298.jpg',
#  'data/oxford-iiit-pet/18/03516.jpg',
#  'data/oxford-iiit-pet/18/03554.jpg',
#  'data/oxford-iiit-pet/19/00244.jpg',
#  'data/oxford-iiit-pet/19/00412.jpg',
#  'data/oxford-iiit-pet/19/00422.jpg',
#  'data/oxford-iiit-pet/19/00540.jpg',
#  'data/oxford-iiit-pet/19/01858.jpg',
#  'data/oxford-iiit-pet/19/02215.jpg',
#  'data/oxford-iiit-pet/19/02247.jpg',
#  'data/oxford-iiit-pet/19/03048.jpg',
#  'data/oxford-iiit-pet/19/03351.jpg',
#  'data/oxford-iiit-pet/19/03533.jpg',
#  'data/oxford-iiit-pet/2/00413.jpg',
#  'data/oxford-iiit-pet/2/00579.jpg',
#  'data/oxford-iiit-pet/2/01036.jpg',
#  'data/oxford-iiit-pet/2/01056.jpg',
#  'data/oxford-iiit-pet/2/01535.jpg',
#  'data/oxford-iiit-pet/2/02205.jpg',
#  'data/oxford-iiit-pet/2/02438.jpg',
#  'data/oxford-iiit-pet/2/02779.jpg',
#  'data/oxford-iiit-pet/2/02987.jpg',
#  'data/oxford-iiit-pet/2/03321.jpg',
#  'data/oxford-iiit-pet/20/00546.jpg',
#  'data/oxford-iiit-pet/20/00624.jpg',
#  'data/oxford-iiit-pet/20/00816.jpg',
#  'data/oxford-iiit-pet/20/01148.jpg',
#  'data/oxford-iiit-pet/20/02051.jpg',
#  'data/oxford-iiit-pet/20/02207.jpg',
#  'data/oxford-iiit-pet/20/02521.jpg',
#  'data/oxford-iiit-pet/20/02570.jpg',
#  'data/oxford-iiit-pet/20/02624.jpg',
#  'data/oxford-iiit-pet/20/02745.jpg',
#  'data/oxford-iiit-pet/21/00335.jpg',
#  'data/oxford-iiit-pet/21/00487.jpg',
#  'data/oxford-iiit-pet/21/00600.jpg',
#  'data/oxford-iiit-pet/21/00775.jpg',
#  'data/oxford-iiit-pet/21/01327.jpg',
#  'data/oxford-iiit-pet/21/01672.jpg',
#  'data/oxford-iiit-pet/21/01735.jpg',
#  'data/oxford-iiit-pet/21/01885.jpg',
#  'data/oxford-iiit-pet/21/03107.jpg',
#  'data/oxford-iiit-pet/21/03306.jpg',
#  'data/oxford-iiit-pet/22/00171.jpg',
#  'data/oxford-iiit-pet/22/00401.jpg',
#  'data/oxford-iiit-pet/22/00581.jpg',
#  'data/oxford-iiit-pet/22/01655.jpg',
#  'data/oxford-iiit-pet/22/01928.jpg',
#  'data/oxford-iiit-pet/22/02266.jpg',
#  'data/oxford-iiit-pet/22/02631.jpg',
#  'data/oxford-iiit-pet/22/03037.jpg',
#  'data/oxford-iiit-pet/22/03252.jpg',
#  'data/oxford-iiit-pet/22/03341.jpg',
#  'data/oxford-iiit-pet/23/00220.jpg',
#  'data/oxford-iiit-pet/23/01389.jpg',
#  'data/oxford-iiit-pet/23/01648.jpg',
#  'data/oxford-iiit-pet/23/01694.jpg',
#  'data/oxford-iiit-pet/23/01821.jpg',
#  'data/oxford-iiit-pet/23/02221.jpg',
#  'data/oxford-iiit-pet/23/02800.jpg',
#  'data/oxford-iiit-pet/23/02817.jpg',
#  'data/oxford-iiit-pet/23/03060.jpg',
#  'data/oxford-iiit-pet/23/03064.jpg',
#  'data/oxford-iiit-pet/24/00093.jpg',
#  'data/oxford-iiit-pet/24/00789.jpg',
#  'data/oxford-iiit-pet/24/01482.jpg',
#  'data/oxford-iiit-pet/24/01691.jpg',
#  'data/oxford-iiit-pet/24/03143.jpg',
#  'data/oxford-iiit-pet/24/03292.jpg',
#  'data/oxford-iiit-pet/24/03310.jpg',
#  'data/oxford-iiit-pet/24/03328.jpg',
#  'data/oxford-iiit-pet/24/03499.jpg',
#  'data/oxford-iiit-pet/24/03582.jpg',
#  'data/oxford-iiit-pet/25/00009.jpg',
#  'data/oxford-iiit-pet/25/00321.jpg',
#  'data/oxford-iiit-pet/25/00732.jpg',
#  'data/oxford-iiit-pet/25/01230.jpg',
#  'data/oxford-iiit-pet/25/01307.jpg',
#  'data/oxford-iiit-pet/25/01329.jpg',
#  'data/oxford-iiit-pet/25/01652.jpg',
#  'data/oxford-iiit-pet/25/02257.jpg',
#  'data/oxford-iiit-pet/25/02345.jpg',
#  'data/oxford-iiit-pet/25/03124.jpg',
#  'data/oxford-iiit-pet/26/00079.jpg',
#  'data/oxford-iiit-pet/26/00532.jpg',
#  'data/oxford-iiit-pet/26/00916.jpg',
#  'data/oxford-iiit-pet/26/01711.jpg',
#  'data/oxford-iiit-pet/26/02580.jpg',
#  'data/oxford-iiit-pet/26/02654.jpg',
#  'data/oxford-iiit-pet/26/02799.jpg',
#  'data/oxford-iiit-pet/26/03361.jpg',
#  'data/oxford-iiit-pet/26/03469.jpg',
#  'data/oxford-iiit-pet/26/03562.jpg',
#  'data/oxford-iiit-pet/27/00377.jpg',
#  'data/oxford-iiit-pet/27/00497.jpg',
#  'data/oxford-iiit-pet/27/00557.jpg',
#  'data/oxford-iiit-pet/27/01137.jpg',
#  'data/oxford-iiit-pet/27/01209.jpg',
#  'data/oxford-iiit-pet/27/01413.jpg',
#  'data/oxford-iiit-pet/27/01901.jpg',
#  'data/oxford-iiit-pet/27/02577.jpg',
#  'data/oxford-iiit-pet/27/02989.jpg',
#  'data/oxford-iiit-pet/27/03380.jpg',
#  'data/oxford-iiit-pet/28/00637.jpg',
#  'data/oxford-iiit-pet/28/00764.jpg',
#  'data/oxford-iiit-pet/28/01021.jpg',
#  'data/oxford-iiit-pet/28/01417.jpg',
#  'data/oxford-iiit-pet/28/01508.jpg',
#  'data/oxford-iiit-pet/28/01557.jpg',
#  'data/oxford-iiit-pet/28/02018.jpg',
#  'data/oxford-iiit-pet/28/02090.jpg',
#  'data/oxford-iiit-pet/28/03586.jpg',
#  'data/oxford-iiit-pet/28/03595.jpg',
#  'data/oxford-iiit-pet/29/00281.jpg',
#  'data/oxford-iiit-pet/29/00776.jpg',
#  'data/oxford-iiit-pet/29/00977.jpg',
#  'data/oxford-iiit-pet/29/01603.jpg',
#  'data/oxford-iiit-pet/29/01625.jpg',
#  'data/oxford-iiit-pet/29/01850.jpg',
#  'data/oxford-iiit-pet/29/02547.jpg',
#  'data/oxford-iiit-pet/29/02734.jpg',
#  'data/oxford-iiit-pet/29/03137.jpg',
#  'data/oxford-iiit-pet/29/03289.jpg',
#  'data/oxford-iiit-pet/3/00238.jpg',
#  'data/oxford-iiit-pet/3/00475.jpg',
#  'data/oxford-iiit-pet/3/01149.jpg',
#  'data/oxford-iiit-pet/3/01177.jpg',
#  'data/oxford-iiit-pet/3/02259.jpg',
#  'data/oxford-iiit-pet/3/02594.jpg',
#  'data/oxford-iiit-pet/3/02612.jpg',
#  'data/oxford-iiit-pet/3/02811.jpg',
#  'data/oxford-iiit-pet/3/03175.jpg',
#  'data/oxford-iiit-pet/3/03441.jpg',
#  'data/oxford-iiit-pet/30/00550.jpg',
#  'data/oxford-iiit-pet/30/02329.jpg',
#  'data/oxford-iiit-pet/30/02439.jpg',
#  'data/oxford-iiit-pet/30/02514.jpg',
#  'data/oxford-iiit-pet/30/02544.jpg',
#  'data/oxford-iiit-pet/30/02679.jpg',
#  'data/oxford-iiit-pet/30/02943.jpg',
#  'data/oxford-iiit-pet/30/03278.jpg',
#  'data/oxford-iiit-pet/30/03293.jpg',
#  'data/oxford-iiit-pet/30/03404.jpg',
#  'data/oxford-iiit-pet/31/00516.jpg',
#  'data/oxford-iiit-pet/31/00734.jpg',
#  'data/oxford-iiit-pet/31/01268.jpg',
#  'data/oxford-iiit-pet/31/01471.jpg',
#  'data/oxford-iiit-pet/31/02100.jpg',
#  'data/oxford-iiit-pet/31/02175.jpg',
#  'data/oxford-iiit-pet/31/03042.jpg',
#  'data/oxford-iiit-pet/31/03117.jpg',
#  'data/oxford-iiit-pet/31/03463.jpg',
#  'data/oxford-iiit-pet/31/03486.jpg',
#  'data/oxford-iiit-pet/32/00586.jpg',
#  'data/oxford-iiit-pet/32/00690.jpg',
#  'data/oxford-iiit-pet/32/00883.jpg',
#  'data/oxford-iiit-pet/32/00891.jpg',
#  'data/oxford-iiit-pet/32/01126.jpg',
#  'data/oxford-iiit-pet/32/02748.jpg',
#  'data/oxford-iiit-pet/32/03028.jpg',
#  'data/oxford-iiit-pet/32/03034.jpg',
#  'data/oxford-iiit-pet/32/03364.jpg',
#  'data/oxford-iiit-pet/32/03665.jpg',
#  'data/oxford-iiit-pet/33/00415.jpg',
#  'data/oxford-iiit-pet/33/00610.jpg',
#  'data/oxford-iiit-pet/33/01486.jpg',
#  'data/oxford-iiit-pet/33/02078.jpg',
#  'data/oxford-iiit-pet/33/02095.jpg',
#  'data/oxford-iiit-pet/33/02375.jpg',
#  'data/oxford-iiit-pet/33/02520.jpg',
#  'data/oxford-iiit-pet/33/02582.jpg',
#  'data/oxford-iiit-pet/33/02617.jpg',
#  'data/oxford-iiit-pet/33/03247.jpg',
#  'data/oxford-iiit-pet/34/00276.jpg',
#  'data/oxford-iiit-pet/34/00647.jpg',
#  'data/oxford-iiit-pet/34/01269.jpg',
#  'data/oxford-iiit-pet/34/01373.jpg',
#  'data/oxford-iiit-pet/34/01580.jpg',
#  'data/oxford-iiit-pet/34/02073.jpg',
#  'data/oxford-iiit-pet/34/02430.jpg',
#  'data/oxford-iiit-pet/34/02626.jpg',
#  'data/oxford-iiit-pet/34/02719.jpg',
#  'data/oxford-iiit-pet/34/02947.jpg',
#  'data/oxford-iiit-pet/35/00243.jpg',
#  'data/oxford-iiit-pet/35/01163.jpg',
#  'data/oxford-iiit-pet/35/01463.jpg',
#  'data/oxford-iiit-pet/35/01594.jpg',
#  'data/oxford-iiit-pet/35/01894.jpg',
#  'data/oxford-iiit-pet/35/02178.jpg',
#  'data/oxford-iiit-pet/35/02609.jpg',
#  'data/oxford-iiit-pet/35/03269.jpg',
#  'data/oxford-iiit-pet/35/03343.jpg',
#  'data/oxford-iiit-pet/35/03389.jpg',
#  'data/oxford-iiit-pet/36/00034.jpg',
#  'data/oxford-iiit-pet/36/00135.jpg',
#  'data/oxford-iiit-pet/36/00347.jpg',
#  'data/oxford-iiit-pet/36/00933.jpg',
#  'data/oxford-iiit-pet/36/01397.jpg',
#  'data/oxford-iiit-pet/36/01682.jpg',
#  'data/oxford-iiit-pet/36/02150.jpg',
#  'data/oxford-iiit-pet/36/02421.jpg',
#  'data/oxford-iiit-pet/36/02991.jpg',
#  'data/oxford-iiit-pet/36/03233.jpg',
#  'data/oxford-iiit-pet/4/00267.jpg',
#  'data/oxford-iiit-pet/4/00526.jpg',
#  'data/oxford-iiit-pet/4/00849.jpg',
#  'data/oxford-iiit-pet/4/01192.jpg',
#  'data/oxford-iiit-pet/4/01515.jpg',
#  'data/oxford-iiit-pet/4/02944.jpg',
#  'data/oxford-iiit-pet/4/02975.jpg',
#  'data/oxford-iiit-pet/4/03227.jpg',
#  'data/oxford-iiit-pet/4/03437.jpg',
#  'data/oxford-iiit-pet/4/03619.jpg',
#  'data/oxford-iiit-pet/5/00522.jpg',
#  'data/oxford-iiit-pet/5/00556.jpg',
#  'data/oxford-iiit-pet/5/00751.jpg',
#  'data/oxford-iiit-pet/5/01275.jpg',
#  'data/oxford-iiit-pet/5/01530.jpg',
#  'data/oxford-iiit-pet/5/02304.jpg',
#  'data/oxford-iiit-pet/5/02501.jpg',
#  'data/oxford-iiit-pet/5/02630.jpg',
#  'data/oxford-iiit-pet/5/02716.jpg',
#  'data/oxford-iiit-pet/5/02969.jpg',
#  'data/oxford-iiit-pet/6/00608.jpg',
#  'data/oxford-iiit-pet/6/00911.jpg',
#  'data/oxford-iiit-pet/6/01642.jpg',
#  'data/oxford-iiit-pet/6/01643.jpg',
#  'data/oxford-iiit-pet/6/01701.jpg',
#  'data/oxford-iiit-pet/6/02192.jpg',
#  'data/oxford-iiit-pet/6/02200.jpg',
#  'data/oxford-iiit-pet/6/03148.jpg',
#  'data/oxford-iiit-pet/6/03155.jpg',
#  'data/oxford-iiit-pet/6/03432.jpg',
#  'data/oxford-iiit-pet/7/01600.jpg',
#  'data/oxford-iiit-pet/7/01676.jpg',
#  'data/oxford-iiit-pet/7/01758.jpg',
#  'data/oxford-iiit-pet/7/01961.jpg',
#  'data/oxford-iiit-pet/7/02017.jpg',
#  'data/oxford-iiit-pet/7/02456.jpg',
#  'data/oxford-iiit-pet/7/02480.jpg',
#  'data/oxford-iiit-pet/7/02700.jpg',
#  'data/oxford-iiit-pet/7/03396.jpg',
#  'data/oxford-iiit-pet/7/03518.jpg',
#  'data/oxford-iiit-pet/8/00006.jpg',
#  'data/oxford-iiit-pet/8/00652.jpg',
#  'data/oxford-iiit-pet/8/00724.jpg',
#  'data/oxford-iiit-pet/8/01599.jpg',
#  'data/oxford-iiit-pet/8/01805.jpg',
#  'data/oxford-iiit-pet/8/02355.jpg',
#  'data/oxford-iiit-pet/8/02443.jpg',
#  'data/oxford-iiit-pet/8/02750.jpg',
#  'data/oxford-iiit-pet/8/02780.jpg',
#  'data/oxford-iiit-pet/8/03459.jpg',
#  'data/oxford-iiit-pet/9/00203.jpg',
#  'data/oxford-iiit-pet/9/00515.jpg',
#  'data/oxford-iiit-pet/9/00674.jpg',
#  'data/oxford-iiit-pet/9/01361.jpg',
#  'data/oxford-iiit-pet/9/02680.jpg',
#  'data/oxford-iiit-pet/9/02738.jpg',
#  'data/oxford-iiit-pet/9/03076.jpg',
#  'data/oxford-iiit-pet/9/03330.jpg',
#  'data/oxford-iiit-pet/9/03452.jpg',
#  'data/oxford-iiit-pet/9/03539.jpg'}

# %%
# Filter out rows that are in initial_samples
unlabeled_samples = unlabeled_samples.filter(
    lambda x: x['filepath'] not in initial_filepaths
)

unlabeled_samples
# Out:
# Filter:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Dataset({
#     features: ['label', 'filepath'],
#     num_rows: 3310
# })

# %%
df = unlabeled_samples.to_pandas()
df["label"] = df["label"].apply(lambda x: "cat" if x == 0 else "dog")
df
df.to_parquet("data/oxford-iiit-pet/unlabeled_samples.parquet")
