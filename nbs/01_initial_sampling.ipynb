# %%
from datasets import load_dataset

dataset = load_dataset("dnth/active-learning-imagenette")

dataset
# Out:
# DatasetDict({
#     evaluation: Dataset({
#         features: ['image', 'filepath', 'label_name'],
#         num_rows: 3925
#     })
#     unlabeled: Dataset({
#         features: ['image', 'filepath', 'label_name'],
#         num_rows: 9469
#     })
# })

# %%
dataset["unlabeled"]
# Out:
# Dataset({
#     features: ['image', 'filepath', 'label_name'],
#     num_rows: 9469
# })

# %%
import numpy as np

unique_labels = dataset["unlabeled"].unique('label_name')
samples = []
n_samples_per_class = 10  

for label in unique_labels:
    label_indices = np.where(np.array(dataset["unlabeled"]["label_name"]) == label)[0]
    # Sample 10 random indices without replacement
    random_indices = np.random.choice(label_indices, size=n_samples_per_class, replace=False)
    samples.extend(random_indices)
    
initial_samples = dataset["unlabeled"].select(samples)

# Verify the result (should show 100 rows total, 10 per class)
print(f"Total samples: {len(initial_samples)}")
print("\nSamples per class:")
print(initial_samples.select_columns(['label_name']).to_pandas().value_counts())
# Out:
# Total samples: 100
#
# Samples per class:
# label_name
# English springer    10
# French horn         10
# cassette player     10
# chain saw           10
# church              10
# garbage truck       10
# gas pump            10
# golf ball           10
# parachute           10
# tench               10
# Name: count, dtype: int64

# %%
initial_samples = initial_samples.remove_columns("image")

df = initial_samples.to_pandas()

df
# Out:
#                        filepath       label_name
# 0   data/imagenette/2/00733.jpg  cassette player
# 1   data/imagenette/2/00194.jpg  cassette player
# 2   data/imagenette/2/00583.jpg  cassette player
# 3   data/imagenette/2/00671.jpg  cassette player
# 4   data/imagenette/2/00454.jpg  cassette player
# ..                          ...              ...
# 95  data/imagenette/5/08576.jpg      French horn
# 96  data/imagenette/5/09084.jpg      French horn
# 97  data/imagenette/5/08885.jpg      French horn
# 98  data/imagenette/5/08781.jpg      French horn
# 99  data/imagenette/5/09073.jpg      French horn
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Train a model on the initial samples

# %%
from fastai.vision.all import *

base_path = "."
dls = ImageDataLoaders.from_df(df, 
                               path=base_path,  
                               valid_pct=0.2,
                               fn_col='filepath',  
                               label_col='label_name', 
                               bs=16,  
                               item_tfms=Resize(224, method=ResizeMethod.Crop))

dls.show_batch()

# %%
learn = vision_learner(dls, resnet18, metrics=accuracy, loss_func=LabelSmoothingCrossEntropy()).to_fp16()
learn.lr_find(suggest_funcs=(valley, slide))
# Out:
# /home/dnth/Desktop/active-learning-flywheel/.venv/lib/python3.12/site-packages/fastai/callback/fp16.py:47: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   self.autocast,self.learn.scaler,self.scales = autocast(dtype=dtype),GradScaler(**self.kwargs),L()
# /home/dnth/Desktop/active-learning-flywheel/.venv/lib/python3.12/site-packages/fastai/callback/fp16.py:47: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.autocast,self.learn.scaler,self.scales = autocast(dtype=dtype),GradScaler(**self.kwargs),L()
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/dnth/Desktop/active-learning-flywheel/.venv/lib/python3.12/site-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# SuggestedLRs(valley=0.0010000000474974513, slide=6.309573450380412e-07)

# %%
learn.fine_tune(10, 1e-3, cbs=[ShowGraphCallback()])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.428929</td>
#       <td>2.454435</td>
#       <td>0.300000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.732280</td>
#       <td>1.813860</td>
#       <td>0.450000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.540590</td>
#       <td>1.347557</td>
#       <td>0.650000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.206165</td>
#       <td>1.009147</td>
#       <td>0.800000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.848320</td>
#       <td>0.892752</td>
#       <td>0.800000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.610799</td>
#       <td>0.833622</td>
#       <td>0.850000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.439082</td>
#       <td>0.807510</td>
#       <td>0.900000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.311056</td>
#       <td>0.794201</td>
#       <td>0.950000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.236931</td>
#       <td>0.802371</td>
#       <td>0.900000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.170260</td>
#       <td>0.801870</td>
#       <td>0.900000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.118549</td>
#       <td>0.803231</td>
#       <td>0.900000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Evaluate the model on the validation set

# %%
eval_df = dataset["evaluation"].remove_columns("image").to_pandas()

eval_df
# Out:
#                          filepath       label_name
# 0     data/imagenette/2/00000.jpg  cassette player
# 1     data/imagenette/2/00001.jpg  cassette player
# 2     data/imagenette/2/00002.jpg  cassette player
# 3     data/imagenette/2/00003.jpg  cassette player
# 4     data/imagenette/2/00004.jpg  cassette player
# ...                           ...              ...
# 3920  data/imagenette/5/03920.jpg      French horn
# 3921  data/imagenette/5/03921.jpg      French horn
# 3922  data/imagenette/5/03922.jpg      French horn
# 3923  data/imagenette/5/03923.jpg      French horn
# 3924  data/imagenette/5/03924.jpg      French horn
#
# [3925 rows x 2 columns]

# %%
list_of_images = eval_df["filepath"].tolist()

list_of_images
# Out:
# ['data/imagenette/2/00000.jpg',
#  'data/imagenette/2/00001.jpg',
#  'data/imagenette/2/00002.jpg',
#  'data/imagenette/2/00003.jpg',
#  'data/imagenette/2/00004.jpg',
#  'data/imagenette/2/00005.jpg',
#  'data/imagenette/2/00006.jpg',
#  'data/imagenette/2/00007.jpg',
#  'data/imagenette/2/00008.jpg',
#  'data/imagenette/2/00009.jpg',
#  'data/imagenette/2/00010.jpg',
#  'data/imagenette/2/00011.jpg',
#  'data/imagenette/2/00012.jpg',
#  'data/imagenette/2/00013.jpg',
#  'data/imagenette/2/00014.jpg',
#  'data/imagenette/2/00015.jpg',
#  'data/imagenette/2/00016.jpg',
#  'data/imagenette/2/00017.jpg',
#  'data/imagenette/2/00018.jpg',
#  'data/imagenette/2/00019.jpg',
#  'data/imagenette/2/00020.jpg',
#  'data/imagenette/2/00021.jpg',
#  'data/imagenette/2/00022.jpg',
#  'data/imagenette/2/00023.jpg',
#  'data/imagenette/2/00024.jpg',
#  'data/imagenette/2/00025.jpg',
#  'data/imagenette/2/00026.jpg',
#  'data/imagenette/2/00027.jpg',
#  'data/imagenette/2/00028.jpg',
#  'data/imagenette/2/00029.jpg',
#  'data/imagenette/2/00030.jpg',
#  'data/imagenette/2/00031.jpg',
#  'data/imagenette/2/00032.jpg',
#  'data/imagenette/2/00033.jpg',
#  'data/imagenette/2/00034.jpg',
#  'data/imagenette/2/00035.jpg',
#  'data/imagenette/2/00036.jpg',
#  'data/imagenette/2/00037.jpg',
#  'data/imagenette/2/00038.jpg',
#  'data/imagenette/2/00039.jpg',
#  'data/imagenette/2/00040.jpg',
#  'data/imagenette/2/00041.jpg',
#  'data/imagenette/2/00042.jpg',
#  'data/imagenette/2/00043.jpg',
#  'data/imagenette/2/00044.jpg',
#  'data/imagenette/2/00045.jpg',
#  'data/imagenette/2/00046.jpg',
#  'data/imagenette/2/00047.jpg',
#  'data/imagenette/2/00048.jpg',
#  'data/imagenette/2/00049.jpg',
#  'data/imagenette/2/00050.jpg',
#  'data/imagenette/2/00051.jpg',
#  'data/imagenette/2/00052.jpg',
#  'data/imagenette/2/00053.jpg',
#  'data/imagenette/2/00054.jpg',
#  'data/imagenette/2/00055.jpg',
#  'data/imagenette/2/00056.jpg',
#  'data/imagenette/2/00057.jpg',
#  'data/imagenette/2/00058.jpg',
#  'data/imagenette/2/00059.jpg',
#  'data/imagenette/2/00060.jpg',
#  'data/imagenette/2/00061.jpg',
#  'data/imagenette/2/00062.jpg',
#  'data/imagenette/2/00063.jpg',
#  'data/imagenette/2/00064.jpg',
#  'data/imagenette/2/00065.jpg',
#  'data/imagenette/2/00066.jpg',
#  'data/imagenette/2/00067.jpg',
#  'data/imagenette/2/00068.jpg',
#  'data/imagenette/2/00069.jpg',
#  'data/imagenette/2/00070.jpg',
#  'data/imagenette/2/00071.jpg',
#  'data/imagenette/2/00072.jpg',
#  'data/imagenette/2/00073.jpg',
#  'data/imagenette/2/00074.jpg',
#  'data/imagenette/2/00075.jpg',
#  'data/imagenette/2/00076.jpg',
#  'data/imagenette/2/00077.jpg',
#  'data/imagenette/2/00078.jpg',
#  'data/imagenette/2/00079.jpg',
#  'data/imagenette/2/00080.jpg',
#  'data/imagenette/2/00081.jpg',
#  'data/imagenette/2/00082.jpg',
#  'data/imagenette/2/00083.jpg',
#  'data/imagenette/2/00084.jpg',
#  'data/imagenette/2/00085.jpg',
#  'data/imagenette/2/00086.jpg',
#  'data/imagenette/2/00087.jpg',
#  'data/imagenette/2/00088.jpg',
#  'data/imagenette/2/00089.jpg',
#  'data/imagenette/2/00090.jpg',
#  'data/imagenette/2/00091.jpg',
#  'data/imagenette/2/00092.jpg',
#  'data/imagenette/2/00093.jpg',
#  'data/imagenette/2/00094.jpg',
#  'data/imagenette/2/00095.jpg',
#  'data/imagenette/2/00096.jpg',
#  'data/imagenette/2/00097.jpg',
#  'data/imagenette/2/00098.jpg',
#  'data/imagenette/2/00099.jpg',
#  'data/imagenette/2/00100.jpg',
#  'data/imagenette/2/00101.jpg',
#  'data/imagenette/2/00102.jpg',
#  'data/imagenette/2/00103.jpg',
#  'data/imagenette/2/00104.jpg',
#  'data/imagenette/2/00105.jpg',
#  'data/imagenette/2/00106.jpg',
#  'data/imagenette/2/00107.jpg',
#  'data/imagenette/2/00108.jpg',
#  'data/imagenette/2/00109.jpg',
#  'data/imagenette/2/00110.jpg',
#  'data/imagenette/2/00111.jpg',
#  'data/imagenette/2/00112.jpg',
#  'data/imagenette/2/00113.jpg',
#  'data/imagenette/2/00114.jpg',
#  'data/imagenette/2/00115.jpg',
#  'data/imagenette/2/00116.jpg',
#  'data/imagenette/2/00117.jpg',
#  'data/imagenette/2/00118.jpg',
#  'data/imagenette/2/00119.jpg',
#  'data/imagenette/2/00120.jpg',
#  'data/imagenette/2/00121.jpg',
#  'data/imagenette/2/00122.jpg',
#  'data/imagenette/2/00123.jpg',
#  'data/imagenette/2/00124.jpg',
#  'data/imagenette/2/00125.jpg',
#  'data/imagenette/2/00126.jpg',
#  'data/imagenette/2/00127.jpg',
#  'data/imagenette/2/00128.jpg',
#  'data/imagenette/2/00129.jpg',
#  'data/imagenette/2/00130.jpg',
#  'data/imagenette/2/00131.jpg',
#  'data/imagenette/2/00132.jpg',
#  'data/imagenette/2/00133.jpg',
#  'data/imagenette/2/00134.jpg',
#  'data/imagenette/2/00135.jpg',
#  'data/imagenette/2/00136.jpg',
#  'data/imagenette/2/00137.jpg',
#  'data/imagenette/2/00138.jpg',
#  'data/imagenette/2/00139.jpg',
#  'data/imagenette/2/00140.jpg',
#  'data/imagenette/2/00141.jpg',
#  'data/imagenette/2/00142.jpg',
#  'data/imagenette/2/00143.jpg',
#  'data/imagenette/2/00144.jpg',
#  'data/imagenette/2/00145.jpg',
#  'data/imagenette/2/00146.jpg',
#  'data/imagenette/2/00147.jpg',
#  'data/imagenette/2/00148.jpg',
#  'data/imagenette/2/00149.jpg',
#  'data/imagenette/2/00150.jpg',
#  'data/imagenette/2/00151.jpg',
#  'data/imagenette/2/00152.jpg',
#  'data/imagenette/2/00153.jpg',
#  'data/imagenette/2/00154.jpg',
#  'data/imagenette/2/00155.jpg',
#  'data/imagenette/2/00156.jpg',
#  'data/imagenette/2/00157.jpg',
#  'data/imagenette/2/00158.jpg',
#  'data/imagenette/2/00159.jpg',
#  'data/imagenette/2/00160.jpg',
#  'data/imagenette/2/00161.jpg',
#  'data/imagenette/2/00162.jpg',
#  'data/imagenette/2/00163.jpg',
#  'data/imagenette/2/00164.jpg',
#  'data/imagenette/2/00165.jpg',
#  'data/imagenette/2/00166.jpg',
#  'data/imagenette/2/00167.jpg',
#  'data/imagenette/2/00168.jpg',
#  'data/imagenette/2/00169.jpg',
#  'data/imagenette/2/00170.jpg',
#  'data/imagenette/2/00171.jpg',
#  'data/imagenette/2/00172.jpg',
#  'data/imagenette/2/00173.jpg',
#  'data/imagenette/2/00174.jpg',
#  'data/imagenette/2/00175.jpg',
#  'data/imagenette/2/00176.jpg',
#  'data/imagenette/2/00177.jpg',
#  'data/imagenette/2/00178.jpg',
#  'data/imagenette/2/00179.jpg',
#  'data/imagenette/2/00180.jpg',
#  'data/imagenette/2/00181.jpg',
#  'data/imagenette/2/00182.jpg',
#  'data/imagenette/2/00183.jpg',
#  'data/imagenette/2/00184.jpg',
#  'data/imagenette/2/00185.jpg',
#  'data/imagenette/2/00186.jpg',
#  'data/imagenette/2/00187.jpg',
#  'data/imagenette/2/00188.jpg',
#  'data/imagenette/2/00189.jpg',
#  'data/imagenette/2/00190.jpg',
#  'data/imagenette/2/00191.jpg',
#  'data/imagenette/2/00192.jpg',
#  'data/imagenette/2/00193.jpg',
#  'data/imagenette/2/00194.jpg',
#  'data/imagenette/2/00195.jpg',
#  'data/imagenette/2/00196.jpg',
#  'data/imagenette/2/00197.jpg',
#  'data/imagenette/2/00198.jpg',
#  'data/imagenette/2/00199.jpg',
#  'data/imagenette/2/00200.jpg',
#  'data/imagenette/2/00201.jpg',
#  'data/imagenette/2/00202.jpg',
#  'data/imagenette/2/00203.jpg',
#  'data/imagenette/2/00204.jpg',
#  'data/imagenette/2/00205.jpg',
#  'data/imagenette/2/00206.jpg',
#  'data/imagenette/2/00207.jpg',
#  'data/imagenette/2/00208.jpg',
#  'data/imagenette/2/00209.jpg',
#  'data/imagenette/2/00210.jpg',
#  'data/imagenette/2/00211.jpg',
#  'data/imagenette/2/00212.jpg',
#  'data/imagenette/2/00213.jpg',
#  'data/imagenette/2/00214.jpg',
#  'data/imagenette/2/00215.jpg',
#  'data/imagenette/2/00216.jpg',
#  'data/imagenette/2/00217.jpg',
#  'data/imagenette/2/00218.jpg',
#  'data/imagenette/2/00219.jpg',
#  'data/imagenette/2/00220.jpg',
#  'data/imagenette/2/00221.jpg',
#  'data/imagenette/2/00222.jpg',
#  'data/imagenette/2/00223.jpg',
#  'data/imagenette/2/00224.jpg',
#  'data/imagenette/2/00225.jpg',
#  'data/imagenette/2/00226.jpg',
#  'data/imagenette/2/00227.jpg',
#  'data/imagenette/2/00228.jpg',
#  'data/imagenette/2/00229.jpg',
#  'data/imagenette/2/00230.jpg',
#  'data/imagenette/2/00231.jpg',
#  'data/imagenette/2/00232.jpg',
#  'data/imagenette/2/00233.jpg',
#  'data/imagenette/2/00234.jpg',
#  'data/imagenette/2/00235.jpg',
#  'data/imagenette/2/00236.jpg',
#  'data/imagenette/2/00237.jpg',
#  'data/imagenette/2/00238.jpg',
#  'data/imagenette/2/00239.jpg',
#  'data/imagenette/2/00240.jpg',
#  'data/imagenette/2/00241.jpg',
#  'data/imagenette/2/00242.jpg',
#  'data/imagenette/2/00243.jpg',
#  'data/imagenette/2/00244.jpg',
#  'data/imagenette/2/00245.jpg',
#  'data/imagenette/2/00246.jpg',
#  'data/imagenette/2/00247.jpg',
#  'data/imagenette/2/00248.jpg',
#  'data/imagenette/2/00249.jpg',
#  'data/imagenette/2/00250.jpg',
#  'data/imagenette/2/00251.jpg',
#  'data/imagenette/2/00252.jpg',
#  'data/imagenette/2/00253.jpg',
#  'data/imagenette/2/00254.jpg',
#  'data/imagenette/2/00255.jpg',
#  'data/imagenette/2/00256.jpg',
#  'data/imagenette/2/00257.jpg',
#  'data/imagenette/2/00258.jpg',
#  'data/imagenette/2/00259.jpg',
#  'data/imagenette/2/00260.jpg',
#  'data/imagenette/2/00261.jpg',
#  'data/imagenette/2/00262.jpg',
#  'data/imagenette/2/00263.jpg',
#  'data/imagenette/2/00264.jpg',
#  'data/imagenette/2/00265.jpg',
#  'data/imagenette/2/00266.jpg',
#  'data/imagenette/2/00267.jpg',
#  'data/imagenette/2/00268.jpg',
#  'data/imagenette/2/00269.jpg',
#  'data/imagenette/2/00270.jpg',
#  'data/imagenette/2/00271.jpg',
#  'data/imagenette/2/00272.jpg',
#  'data/imagenette/2/00273.jpg',
#  'data/imagenette/2/00274.jpg',
#  'data/imagenette/2/00275.jpg',
#  'data/imagenette/2/00276.jpg',
#  'data/imagenette/2/00277.jpg',
#  'data/imagenette/2/00278.jpg',
#  'data/imagenette/2/00279.jpg',
#  'data/imagenette/2/00280.jpg',
#  'data/imagenette/2/00281.jpg',
#  'data/imagenette/2/00282.jpg',
#  'data/imagenette/2/00283.jpg',
#  'data/imagenette/2/00284.jpg',
#  'data/imagenette/2/00285.jpg',
#  'data/imagenette/2/00286.jpg',
#  'data/imagenette/2/00287.jpg',
#  'data/imagenette/2/00288.jpg',
#  'data/imagenette/2/00289.jpg',
#  'data/imagenette/2/00290.jpg',
#  'data/imagenette/2/00291.jpg',
#  'data/imagenette/2/00292.jpg',
#  'data/imagenette/2/00293.jpg',
#  'data/imagenette/2/00294.jpg',
#  'data/imagenette/2/00295.jpg',
#  'data/imagenette/2/00296.jpg',
#  'data/imagenette/2/00297.jpg',
#  'data/imagenette/2/00298.jpg',
#  'data/imagenette/2/00299.jpg',
#  'data/imagenette/2/00300.jpg',
#  'data/imagenette/2/00301.jpg',
#  'data/imagenette/2/00302.jpg',
#  'data/imagenette/2/00303.jpg',
#  'data/imagenette/2/00304.jpg',
#  'data/imagenette/2/00305.jpg',
#  'data/imagenette/2/00306.jpg',
#  'data/imagenette/2/00307.jpg',
#  'data/imagenette/2/00308.jpg',
#  'data/imagenette/2/00309.jpg',
#  'data/imagenette/2/00310.jpg',
#  'data/imagenette/2/00311.jpg',
#  'data/imagenette/2/00312.jpg',
#  'data/imagenette/2/00313.jpg',
#  'data/imagenette/2/00314.jpg',
#  'data/imagenette/2/00315.jpg',
#  'data/imagenette/2/00316.jpg',
#  'data/imagenette/2/00317.jpg',
#  'data/imagenette/2/00318.jpg',
#  'data/imagenette/2/00319.jpg',
#  'data/imagenette/2/00320.jpg',
#  'data/imagenette/2/00321.jpg',
#  'data/imagenette/2/00322.jpg',
#  'data/imagenette/2/00323.jpg',
#  'data/imagenette/2/00324.jpg',
#  'data/imagenette/2/00325.jpg',
#  'data/imagenette/2/00326.jpg',
#  'data/imagenette/2/00327.jpg',
#  'data/imagenette/2/00328.jpg',
#  'data/imagenette/2/00329.jpg',
#  'data/imagenette/2/00330.jpg',
#  'data/imagenette/2/00331.jpg',
#  'data/imagenette/2/00332.jpg',
#  'data/imagenette/2/00333.jpg',
#  'data/imagenette/2/00334.jpg',
#  'data/imagenette/2/00335.jpg',
#  'data/imagenette/2/00336.jpg',
#  'data/imagenette/2/00337.jpg',
#  'data/imagenette/2/00338.jpg',
#  'data/imagenette/2/00339.jpg',
#  'data/imagenette/2/00340.jpg',
#  'data/imagenette/2/00341.jpg',
#  'data/imagenette/2/00342.jpg',
#  'data/imagenette/2/00343.jpg',
#  'data/imagenette/2/00344.jpg',
#  'data/imagenette/2/00345.jpg',
#  'data/imagenette/2/00346.jpg',
#  'data/imagenette/2/00347.jpg',
#  'data/imagenette/2/00348.jpg',
#  'data/imagenette/2/00349.jpg',
#  'data/imagenette/2/00350.jpg',
#  'data/imagenette/2/00351.jpg',
#  'data/imagenette/2/00352.jpg',
#  'data/imagenette/2/00353.jpg',
#  'data/imagenette/2/00354.jpg',
#  'data/imagenette/2/00355.jpg',
#  'data/imagenette/2/00356.jpg',
#  'data/imagenette/0/00357.jpg',
#  'data/imagenette/0/00358.jpg',
#  'data/imagenette/0/00359.jpg',
#  'data/imagenette/0/00360.jpg',
#  'data/imagenette/0/00361.jpg',
#  'data/imagenette/0/00362.jpg',
#  'data/imagenette/0/00363.jpg',
#  'data/imagenette/0/00364.jpg',
#  'data/imagenette/0/00365.jpg',
#  'data/imagenette/0/00366.jpg',
#  'data/imagenette/0/00367.jpg',
#  'data/imagenette/0/00368.jpg',
#  'data/imagenette/0/00369.jpg',
#  'data/imagenette/0/00370.jpg',
#  'data/imagenette/0/00371.jpg',
#  'data/imagenette/0/00372.jpg',
#  'data/imagenette/0/00373.jpg',
#  'data/imagenette/0/00374.jpg',
#  'data/imagenette/0/00375.jpg',
#  'data/imagenette/0/00376.jpg',
#  'data/imagenette/0/00377.jpg',
#  'data/imagenette/0/00378.jpg',
#  'data/imagenette/0/00379.jpg',
#  'data/imagenette/0/00380.jpg',
#  'data/imagenette/0/00381.jpg',
#  'data/imagenette/0/00382.jpg',
#  'data/imagenette/0/00383.jpg',
#  'data/imagenette/0/00384.jpg',
#  'data/imagenette/0/00385.jpg',
#  'data/imagenette/0/00386.jpg',
#  'data/imagenette/0/00387.jpg',
#  'data/imagenette/0/00388.jpg',
#  'data/imagenette/0/00389.jpg',
#  'data/imagenette/0/00390.jpg',
#  'data/imagenette/0/00391.jpg',
#  'data/imagenette/0/00392.jpg',
#  'data/imagenette/0/00393.jpg',
#  'data/imagenette/0/00394.jpg',
#  'data/imagenette/0/00395.jpg',
#  'data/imagenette/0/00396.jpg',
#  'data/imagenette/0/00397.jpg',
#  'data/imagenette/0/00398.jpg',
#  'data/imagenette/0/00399.jpg',
#  'data/imagenette/0/00400.jpg',
#  'data/imagenette/0/00401.jpg',
#  'data/imagenette/0/00402.jpg',
#  'data/imagenette/0/00403.jpg',
#  'data/imagenette/0/00404.jpg',
#  'data/imagenette/0/00405.jpg',
#  'data/imagenette/0/00406.jpg',
#  'data/imagenette/0/00407.jpg',
#  'data/imagenette/0/00408.jpg',
#  'data/imagenette/0/00409.jpg',
#  'data/imagenette/0/00410.jpg',
#  'data/imagenette/0/00411.jpg',
#  'data/imagenette/0/00412.jpg',
#  'data/imagenette/0/00413.jpg',
#  'data/imagenette/0/00414.jpg',
#  'data/imagenette/0/00415.jpg',
#  'data/imagenette/0/00416.jpg',
#  'data/imagenette/0/00417.jpg',
#  'data/imagenette/0/00418.jpg',
#  'data/imagenette/0/00419.jpg',
#  'data/imagenette/0/00420.jpg',
#  'data/imagenette/0/00421.jpg',
#  'data/imagenette/0/00422.jpg',
#  'data/imagenette/0/00423.jpg',
#  'data/imagenette/0/00424.jpg',
#  'data/imagenette/0/00425.jpg',
#  'data/imagenette/0/00426.jpg',
#  'data/imagenette/0/00427.jpg',
#  'data/imagenette/0/00428.jpg',
#  'data/imagenette/0/00429.jpg',
#  'data/imagenette/0/00430.jpg',
#  'data/imagenette/0/00431.jpg',
#  'data/imagenette/0/00432.jpg',
#  'data/imagenette/0/00433.jpg',
#  'data/imagenette/0/00434.jpg',
#  'data/imagenette/0/00435.jpg',
#  'data/imagenette/0/00436.jpg',
#  'data/imagenette/0/00437.jpg',
#  'data/imagenette/0/00438.jpg',
#  'data/imagenette/0/00439.jpg',
#  'data/imagenette/0/00440.jpg',
#  'data/imagenette/0/00441.jpg',
#  'data/imagenette/0/00442.jpg',
#  'data/imagenette/0/00443.jpg',
#  'data/imagenette/0/00444.jpg',
#  'data/imagenette/0/00445.jpg',
#  'data/imagenette/0/00446.jpg',
#  'data/imagenette/0/00447.jpg',
#  'data/imagenette/0/00448.jpg',
#  'data/imagenette/0/00449.jpg',
#  'data/imagenette/0/00450.jpg',
#  'data/imagenette/0/00451.jpg',
#  'data/imagenette/0/00452.jpg',
#  'data/imagenette/0/00453.jpg',
#  'data/imagenette/0/00454.jpg',
#  'data/imagenette/0/00455.jpg',
#  'data/imagenette/0/00456.jpg',
#  'data/imagenette/0/00457.jpg',
#  'data/imagenette/0/00458.jpg',
#  'data/imagenette/0/00459.jpg',
#  'data/imagenette/0/00460.jpg',
#  'data/imagenette/0/00461.jpg',
#  'data/imagenette/0/00462.jpg',
#  'data/imagenette/0/00463.jpg',
#  'data/imagenette/0/00464.jpg',
#  'data/imagenette/0/00465.jpg',
#  'data/imagenette/0/00466.jpg',
#  'data/imagenette/0/00467.jpg',
#  'data/imagenette/0/00468.jpg',
#  'data/imagenette/0/00469.jpg',
#  'data/imagenette/0/00470.jpg',
#  'data/imagenette/0/00471.jpg',
#  'data/imagenette/0/00472.jpg',
#  'data/imagenette/0/00473.jpg',
#  'data/imagenette/0/00474.jpg',
#  'data/imagenette/0/00475.jpg',
#  'data/imagenette/0/00476.jpg',
#  'data/imagenette/0/00477.jpg',
#  'data/imagenette/0/00478.jpg',
#  'data/imagenette/0/00479.jpg',
#  'data/imagenette/0/00480.jpg',
#  'data/imagenette/0/00481.jpg',
#  'data/imagenette/0/00482.jpg',
#  'data/imagenette/0/00483.jpg',
#  'data/imagenette/0/00484.jpg',
#  'data/imagenette/0/00485.jpg',
#  'data/imagenette/0/00486.jpg',
#  'data/imagenette/0/00487.jpg',
#  'data/imagenette/0/00488.jpg',
#  'data/imagenette/0/00489.jpg',
#  'data/imagenette/0/00490.jpg',
#  'data/imagenette/0/00491.jpg',
#  'data/imagenette/0/00492.jpg',
#  'data/imagenette/0/00493.jpg',
#  'data/imagenette/0/00494.jpg',
#  'data/imagenette/0/00495.jpg',
#  'data/imagenette/0/00496.jpg',
#  'data/imagenette/0/00497.jpg',
#  'data/imagenette/0/00498.jpg',
#  'data/imagenette/0/00499.jpg',
#  'data/imagenette/0/00500.jpg',
#  'data/imagenette/0/00501.jpg',
#  'data/imagenette/0/00502.jpg',
#  'data/imagenette/0/00503.jpg',
#  'data/imagenette/0/00504.jpg',
#  'data/imagenette/0/00505.jpg',
#  'data/imagenette/0/00506.jpg',
#  'data/imagenette/0/00507.jpg',
#  'data/imagenette/0/00508.jpg',
#  'data/imagenette/0/00509.jpg',
#  'data/imagenette/0/00510.jpg',
#  'data/imagenette/0/00511.jpg',
#  'data/imagenette/0/00512.jpg',
#  'data/imagenette/0/00513.jpg',
#  'data/imagenette/0/00514.jpg',
#  'data/imagenette/0/00515.jpg',
#  'data/imagenette/0/00516.jpg',
#  'data/imagenette/0/00517.jpg',
#  'data/imagenette/0/00518.jpg',
#  'data/imagenette/0/00519.jpg',
#  'data/imagenette/0/00520.jpg',
#  'data/imagenette/0/00521.jpg',
#  'data/imagenette/0/00522.jpg',
#  'data/imagenette/0/00523.jpg',
#  'data/imagenette/0/00524.jpg',
#  'data/imagenette/0/00525.jpg',
#  'data/imagenette/0/00526.jpg',
#  'data/imagenette/0/00527.jpg',
#  'data/imagenette/0/00528.jpg',
#  'data/imagenette/0/00529.jpg',
#  'data/imagenette/0/00530.jpg',
#  'data/imagenette/0/00531.jpg',
#  'data/imagenette/0/00532.jpg',
#  'data/imagenette/0/00533.jpg',
#  'data/imagenette/0/00534.jpg',
#  'data/imagenette/0/00535.jpg',
#  'data/imagenette/0/00536.jpg',
#  'data/imagenette/0/00537.jpg',
#  'data/imagenette/0/00538.jpg',
#  'data/imagenette/0/00539.jpg',
#  'data/imagenette/0/00540.jpg',
#  'data/imagenette/0/00541.jpg',
#  'data/imagenette/0/00542.jpg',
#  'data/imagenette/0/00543.jpg',
#  'data/imagenette/0/00544.jpg',
#  'data/imagenette/0/00545.jpg',
#  'data/imagenette/0/00546.jpg',
#  'data/imagenette/0/00547.jpg',
#  'data/imagenette/0/00548.jpg',
#  'data/imagenette/0/00549.jpg',
#  'data/imagenette/0/00550.jpg',
#  'data/imagenette/0/00551.jpg',
#  'data/imagenette/0/00552.jpg',
#  'data/imagenette/0/00553.jpg',
#  'data/imagenette/0/00554.jpg',
#  'data/imagenette/0/00555.jpg',
#  'data/imagenette/0/00556.jpg',
#  'data/imagenette/0/00557.jpg',
#  'data/imagenette/0/00558.jpg',
#  'data/imagenette/0/00559.jpg',
#  'data/imagenette/0/00560.jpg',
#  'data/imagenette/0/00561.jpg',
#  'data/imagenette/0/00562.jpg',
#  'data/imagenette/0/00563.jpg',
#  'data/imagenette/0/00564.jpg',
#  'data/imagenette/0/00565.jpg',
#  'data/imagenette/0/00566.jpg',
#  'data/imagenette/0/00567.jpg',
#  'data/imagenette/0/00568.jpg',
#  'data/imagenette/0/00569.jpg',
#  'data/imagenette/0/00570.jpg',
#  'data/imagenette/0/00571.jpg',
#  'data/imagenette/0/00572.jpg',
#  'data/imagenette/0/00573.jpg',
#  'data/imagenette/0/00574.jpg',
#  'data/imagenette/0/00575.jpg',
#  'data/imagenette/0/00576.jpg',
#  'data/imagenette/0/00577.jpg',
#  'data/imagenette/0/00578.jpg',
#  'data/imagenette/0/00579.jpg',
#  'data/imagenette/0/00580.jpg',
#  'data/imagenette/0/00581.jpg',
#  'data/imagenette/0/00582.jpg',
#  'data/imagenette/0/00583.jpg',
#  'data/imagenette/0/00584.jpg',
#  'data/imagenette/0/00585.jpg',
#  'data/imagenette/0/00586.jpg',
#  'data/imagenette/0/00587.jpg',
#  'data/imagenette/0/00588.jpg',
#  'data/imagenette/0/00589.jpg',
#  'data/imagenette/0/00590.jpg',
#  'data/imagenette/0/00591.jpg',
#  'data/imagenette/0/00592.jpg',
#  'data/imagenette/0/00593.jpg',
#  'data/imagenette/0/00594.jpg',
#  'data/imagenette/0/00595.jpg',
#  'data/imagenette/0/00596.jpg',
#  'data/imagenette/0/00597.jpg',
#  'data/imagenette/0/00598.jpg',
#  'data/imagenette/0/00599.jpg',
#  'data/imagenette/0/00600.jpg',
#  'data/imagenette/0/00601.jpg',
#  'data/imagenette/0/00602.jpg',
#  'data/imagenette/0/00603.jpg',
#  'data/imagenette/0/00604.jpg',
#  'data/imagenette/0/00605.jpg',
#  'data/imagenette/0/00606.jpg',
#  'data/imagenette/0/00607.jpg',
#  'data/imagenette/0/00608.jpg',
#  'data/imagenette/0/00609.jpg',
#  'data/imagenette/0/00610.jpg',
#  'data/imagenette/0/00611.jpg',
#  'data/imagenette/0/00612.jpg',
#  'data/imagenette/0/00613.jpg',
#  'data/imagenette/0/00614.jpg',
#  'data/imagenette/0/00615.jpg',
#  'data/imagenette/0/00616.jpg',
#  'data/imagenette/0/00617.jpg',
#  'data/imagenette/0/00618.jpg',
#  'data/imagenette/0/00619.jpg',
#  'data/imagenette/0/00620.jpg',
#  'data/imagenette/0/00621.jpg',
#  'data/imagenette/0/00622.jpg',
#  'data/imagenette/0/00623.jpg',
#  'data/imagenette/0/00624.jpg',
#  'data/imagenette/0/00625.jpg',
#  'data/imagenette/0/00626.jpg',
#  'data/imagenette/0/00627.jpg',
#  'data/imagenette/0/00628.jpg',
#  'data/imagenette/0/00629.jpg',
#  'data/imagenette/0/00630.jpg',
#  'data/imagenette/0/00631.jpg',
#  'data/imagenette/0/00632.jpg',
#  'data/imagenette/0/00633.jpg',
#  'data/imagenette/0/00634.jpg',
#  'data/imagenette/0/00635.jpg',
#  'data/imagenette/0/00636.jpg',
#  'data/imagenette/0/00637.jpg',
#  'data/imagenette/0/00638.jpg',
#  'data/imagenette/0/00639.jpg',
#  'data/imagenette/0/00640.jpg',
#  'data/imagenette/0/00641.jpg',
#  'data/imagenette/0/00642.jpg',
#  'data/imagenette/0/00643.jpg',
#  'data/imagenette/0/00644.jpg',
#  'data/imagenette/0/00645.jpg',
#  'data/imagenette/0/00646.jpg',
#  'data/imagenette/0/00647.jpg',
#  'data/imagenette/0/00648.jpg',
#  'data/imagenette/0/00649.jpg',
#  'data/imagenette/0/00650.jpg',
#  'data/imagenette/0/00651.jpg',
#  'data/imagenette/0/00652.jpg',
#  'data/imagenette/0/00653.jpg',
#  'data/imagenette/0/00654.jpg',
#  'data/imagenette/0/00655.jpg',
#  'data/imagenette/0/00656.jpg',
#  'data/imagenette/0/00657.jpg',
#  'data/imagenette/0/00658.jpg',
#  'data/imagenette/0/00659.jpg',
#  'data/imagenette/0/00660.jpg',
#  'data/imagenette/0/00661.jpg',
#  'data/imagenette/0/00662.jpg',
#  'data/imagenette/0/00663.jpg',
#  'data/imagenette/0/00664.jpg',
#  'data/imagenette/0/00665.jpg',
#  'data/imagenette/0/00666.jpg',
#  'data/imagenette/0/00667.jpg',
#  'data/imagenette/0/00668.jpg',
#  'data/imagenette/0/00669.jpg',
#  'data/imagenette/0/00670.jpg',
#  'data/imagenette/0/00671.jpg',
#  'data/imagenette/0/00672.jpg',
#  'data/imagenette/0/00673.jpg',
#  'data/imagenette/0/00674.jpg',
#  'data/imagenette/0/00675.jpg',
#  'data/imagenette/0/00676.jpg',
#  'data/imagenette/0/00677.jpg',
#  'data/imagenette/0/00678.jpg',
#  'data/imagenette/0/00679.jpg',
#  'data/imagenette/0/00680.jpg',
#  'data/imagenette/0/00681.jpg',
#  'data/imagenette/0/00682.jpg',
#  'data/imagenette/0/00683.jpg',
#  'data/imagenette/0/00684.jpg',
#  'data/imagenette/0/00685.jpg',
#  'data/imagenette/0/00686.jpg',
#  'data/imagenette/0/00687.jpg',
#  'data/imagenette/0/00688.jpg',
#  'data/imagenette/0/00689.jpg',
#  'data/imagenette/0/00690.jpg',
#  'data/imagenette/0/00691.jpg',
#  'data/imagenette/0/00692.jpg',
#  'data/imagenette/0/00693.jpg',
#  'data/imagenette/0/00694.jpg',
#  'data/imagenette/0/00695.jpg',
#  'data/imagenette/0/00696.jpg',
#  'data/imagenette/0/00697.jpg',
#  'data/imagenette/0/00698.jpg',
#  'data/imagenette/0/00699.jpg',
#  'data/imagenette/0/00700.jpg',
#  'data/imagenette/0/00701.jpg',
#  'data/imagenette/0/00702.jpg',
#  'data/imagenette/0/00703.jpg',
#  'data/imagenette/0/00704.jpg',
#  'data/imagenette/0/00705.jpg',
#  'data/imagenette/0/00706.jpg',
#  'data/imagenette/0/00707.jpg',
#  'data/imagenette/0/00708.jpg',
#  'data/imagenette/0/00709.jpg',
#  'data/imagenette/0/00710.jpg',
#  'data/imagenette/0/00711.jpg',
#  'data/imagenette/0/00712.jpg',
#  'data/imagenette/0/00713.jpg',
#  'data/imagenette/0/00714.jpg',
#  'data/imagenette/0/00715.jpg',
#  'data/imagenette/0/00716.jpg',
#  'data/imagenette/0/00717.jpg',
#  'data/imagenette/0/00718.jpg',
#  'data/imagenette/0/00719.jpg',
#  'data/imagenette/0/00720.jpg',
#  'data/imagenette/0/00721.jpg',
#  'data/imagenette/0/00722.jpg',
#  'data/imagenette/0/00723.jpg',
#  'data/imagenette/0/00724.jpg',
#  'data/imagenette/0/00725.jpg',
#  'data/imagenette/0/00726.jpg',
#  'data/imagenette/0/00727.jpg',
#  'data/imagenette/0/00728.jpg',
#  'data/imagenette/0/00729.jpg',
#  'data/imagenette/0/00730.jpg',
#  'data/imagenette/0/00731.jpg',
#  'data/imagenette/0/00732.jpg',
#  'data/imagenette/0/00733.jpg',
#  'data/imagenette/0/00734.jpg',
#  'data/imagenette/0/00735.jpg',
#  'data/imagenette/0/00736.jpg',
#  'data/imagenette/0/00737.jpg',
#  'data/imagenette/0/00738.jpg',
#  'data/imagenette/0/00739.jpg',
#  'data/imagenette/0/00740.jpg',
#  'data/imagenette/0/00741.jpg',
#  'data/imagenette/0/00742.jpg',
#  'data/imagenette/0/00743.jpg',
#  'data/imagenette/3/00744.jpg',
#  'data/imagenette/3/00745.jpg',
#  'data/imagenette/3/00746.jpg',
#  'data/imagenette/3/00747.jpg',
#  'data/imagenette/3/00748.jpg',
#  'data/imagenette/3/00749.jpg',
#  'data/imagenette/3/00750.jpg',
#  'data/imagenette/3/00751.jpg',
#  'data/imagenette/3/00752.jpg',
#  'data/imagenette/3/00753.jpg',
#  'data/imagenette/3/00754.jpg',
#  'data/imagenette/3/00755.jpg',
#  'data/imagenette/3/00756.jpg',
#  'data/imagenette/3/00757.jpg',
#  'data/imagenette/3/00758.jpg',
#  'data/imagenette/3/00759.jpg',
#  'data/imagenette/3/00760.jpg',
#  'data/imagenette/3/00761.jpg',
#  'data/imagenette/3/00762.jpg',
#  'data/imagenette/3/00763.jpg',
#  'data/imagenette/3/00764.jpg',
#  'data/imagenette/3/00765.jpg',
#  'data/imagenette/3/00766.jpg',
#  'data/imagenette/3/00767.jpg',
#  'data/imagenette/3/00768.jpg',
#  'data/imagenette/3/00769.jpg',
#  'data/imagenette/3/00770.jpg',
#  'data/imagenette/3/00771.jpg',
#  'data/imagenette/3/00772.jpg',
#  'data/imagenette/3/00773.jpg',
#  'data/imagenette/3/00774.jpg',
#  'data/imagenette/3/00775.jpg',
#  'data/imagenette/3/00776.jpg',
#  'data/imagenette/3/00777.jpg',
#  'data/imagenette/3/00778.jpg',
#  'data/imagenette/3/00779.jpg',
#  'data/imagenette/3/00780.jpg',
#  'data/imagenette/3/00781.jpg',
#  'data/imagenette/3/00782.jpg',
#  'data/imagenette/3/00783.jpg',
#  'data/imagenette/3/00784.jpg',
#  'data/imagenette/3/00785.jpg',
#  'data/imagenette/3/00786.jpg',
#  'data/imagenette/3/00787.jpg',
#  'data/imagenette/3/00788.jpg',
#  'data/imagenette/3/00789.jpg',
#  'data/imagenette/3/00790.jpg',
#  'data/imagenette/3/00791.jpg',
#  'data/imagenette/3/00792.jpg',
#  'data/imagenette/3/00793.jpg',
#  'data/imagenette/3/00794.jpg',
#  'data/imagenette/3/00795.jpg',
#  'data/imagenette/3/00796.jpg',
#  'data/imagenette/3/00797.jpg',
#  'data/imagenette/3/00798.jpg',
#  'data/imagenette/3/00799.jpg',
#  'data/imagenette/3/00800.jpg',
#  'data/imagenette/3/00801.jpg',
#  'data/imagenette/3/00802.jpg',
#  'data/imagenette/3/00803.jpg',
#  'data/imagenette/3/00804.jpg',
#  'data/imagenette/3/00805.jpg',
#  'data/imagenette/3/00806.jpg',
#  'data/imagenette/3/00807.jpg',
#  'data/imagenette/3/00808.jpg',
#  'data/imagenette/3/00809.jpg',
#  'data/imagenette/3/00810.jpg',
#  'data/imagenette/3/00811.jpg',
#  'data/imagenette/3/00812.jpg',
#  'data/imagenette/3/00813.jpg',
#  'data/imagenette/3/00814.jpg',
#  'data/imagenette/3/00815.jpg',
#  'data/imagenette/3/00816.jpg',
#  'data/imagenette/3/00817.jpg',
#  'data/imagenette/3/00818.jpg',
#  'data/imagenette/3/00819.jpg',
#  'data/imagenette/3/00820.jpg',
#  'data/imagenette/3/00821.jpg',
#  'data/imagenette/3/00822.jpg',
#  'data/imagenette/3/00823.jpg',
#  'data/imagenette/3/00824.jpg',
#  'data/imagenette/3/00825.jpg',
#  'data/imagenette/3/00826.jpg',
#  'data/imagenette/3/00827.jpg',
#  'data/imagenette/3/00828.jpg',
#  'data/imagenette/3/00829.jpg',
#  'data/imagenette/3/00830.jpg',
#  'data/imagenette/3/00831.jpg',
#  'data/imagenette/3/00832.jpg',
#  'data/imagenette/3/00833.jpg',
#  'data/imagenette/3/00834.jpg',
#  'data/imagenette/3/00835.jpg',
#  'data/imagenette/3/00836.jpg',
#  'data/imagenette/3/00837.jpg',
#  'data/imagenette/3/00838.jpg',
#  'data/imagenette/3/00839.jpg',
#  'data/imagenette/3/00840.jpg',
#  'data/imagenette/3/00841.jpg',
#  'data/imagenette/3/00842.jpg',
#  'data/imagenette/3/00843.jpg',
#  'data/imagenette/3/00844.jpg',
#  'data/imagenette/3/00845.jpg',
#  'data/imagenette/3/00846.jpg',
#  'data/imagenette/3/00847.jpg',
#  'data/imagenette/3/00848.jpg',
#  'data/imagenette/3/00849.jpg',
#  'data/imagenette/3/00850.jpg',
#  'data/imagenette/3/00851.jpg',
#  'data/imagenette/3/00852.jpg',
#  'data/imagenette/3/00853.jpg',
#  'data/imagenette/3/00854.jpg',
#  'data/imagenette/3/00855.jpg',
#  'data/imagenette/3/00856.jpg',
#  'data/imagenette/3/00857.jpg',
#  'data/imagenette/3/00858.jpg',
#  'data/imagenette/3/00859.jpg',
#  'data/imagenette/3/00860.jpg',
#  'data/imagenette/3/00861.jpg',
#  'data/imagenette/3/00862.jpg',
#  'data/imagenette/3/00863.jpg',
#  'data/imagenette/3/00864.jpg',
#  'data/imagenette/3/00865.jpg',
#  'data/imagenette/3/00866.jpg',
#  'data/imagenette/3/00867.jpg',
#  'data/imagenette/3/00868.jpg',
#  'data/imagenette/3/00869.jpg',
#  'data/imagenette/3/00870.jpg',
#  'data/imagenette/3/00871.jpg',
#  'data/imagenette/3/00872.jpg',
#  'data/imagenette/3/00873.jpg',
#  'data/imagenette/3/00874.jpg',
#  'data/imagenette/3/00875.jpg',
#  'data/imagenette/3/00876.jpg',
#  'data/imagenette/3/00877.jpg',
#  'data/imagenette/3/00878.jpg',
#  'data/imagenette/3/00879.jpg',
#  'data/imagenette/3/00880.jpg',
#  'data/imagenette/3/00881.jpg',
#  'data/imagenette/3/00882.jpg',
#  'data/imagenette/3/00883.jpg',
#  'data/imagenette/3/00884.jpg',
#  'data/imagenette/3/00885.jpg',
#  'data/imagenette/3/00886.jpg',
#  'data/imagenette/3/00887.jpg',
#  'data/imagenette/3/00888.jpg',
#  'data/imagenette/3/00889.jpg',
#  'data/imagenette/3/00890.jpg',
#  'data/imagenette/3/00891.jpg',
#  'data/imagenette/3/00892.jpg',
#  'data/imagenette/3/00893.jpg',
#  'data/imagenette/3/00894.jpg',
#  'data/imagenette/3/00895.jpg',
#  'data/imagenette/3/00896.jpg',
#  'data/imagenette/3/00897.jpg',
#  'data/imagenette/3/00898.jpg',
#  'data/imagenette/3/00899.jpg',
#  'data/imagenette/3/00900.jpg',
#  'data/imagenette/3/00901.jpg',
#  'data/imagenette/3/00902.jpg',
#  'data/imagenette/3/00903.jpg',
#  'data/imagenette/3/00904.jpg',
#  'data/imagenette/3/00905.jpg',
#  'data/imagenette/3/00906.jpg',
#  'data/imagenette/3/00907.jpg',
#  'data/imagenette/3/00908.jpg',
#  'data/imagenette/3/00909.jpg',
#  'data/imagenette/3/00910.jpg',
#  'data/imagenette/3/00911.jpg',
#  'data/imagenette/3/00912.jpg',
#  'data/imagenette/3/00913.jpg',
#  'data/imagenette/3/00914.jpg',
#  'data/imagenette/3/00915.jpg',
#  'data/imagenette/3/00916.jpg',
#  'data/imagenette/3/00917.jpg',
#  'data/imagenette/3/00918.jpg',
#  'data/imagenette/3/00919.jpg',
#  'data/imagenette/3/00920.jpg',
#  'data/imagenette/3/00921.jpg',
#  'data/imagenette/3/00922.jpg',
#  'data/imagenette/3/00923.jpg',
#  'data/imagenette/3/00924.jpg',
#  'data/imagenette/3/00925.jpg',
#  'data/imagenette/3/00926.jpg',
#  'data/imagenette/3/00927.jpg',
#  'data/imagenette/3/00928.jpg',
#  'data/imagenette/3/00929.jpg',
#  'data/imagenette/3/00930.jpg',
#  'data/imagenette/3/00931.jpg',
#  'data/imagenette/3/00932.jpg',
#  'data/imagenette/3/00933.jpg',
#  'data/imagenette/3/00934.jpg',
#  'data/imagenette/3/00935.jpg',
#  'data/imagenette/3/00936.jpg',
#  'data/imagenette/3/00937.jpg',
#  'data/imagenette/3/00938.jpg',
#  'data/imagenette/3/00939.jpg',
#  'data/imagenette/3/00940.jpg',
#  'data/imagenette/3/00941.jpg',
#  'data/imagenette/3/00942.jpg',
#  'data/imagenette/3/00943.jpg',
#  'data/imagenette/3/00944.jpg',
#  'data/imagenette/3/00945.jpg',
#  'data/imagenette/3/00946.jpg',
#  'data/imagenette/3/00947.jpg',
#  'data/imagenette/3/00948.jpg',
#  'data/imagenette/3/00949.jpg',
#  'data/imagenette/3/00950.jpg',
#  'data/imagenette/3/00951.jpg',
#  'data/imagenette/3/00952.jpg',
#  'data/imagenette/3/00953.jpg',
#  'data/imagenette/3/00954.jpg',
#  'data/imagenette/3/00955.jpg',
#  'data/imagenette/3/00956.jpg',
#  'data/imagenette/3/00957.jpg',
#  'data/imagenette/3/00958.jpg',
#  'data/imagenette/3/00959.jpg',
#  'data/imagenette/3/00960.jpg',
#  'data/imagenette/3/00961.jpg',
#  'data/imagenette/3/00962.jpg',
#  'data/imagenette/3/00963.jpg',
#  'data/imagenette/3/00964.jpg',
#  'data/imagenette/3/00965.jpg',
#  'data/imagenette/3/00966.jpg',
#  'data/imagenette/3/00967.jpg',
#  'data/imagenette/3/00968.jpg',
#  'data/imagenette/3/00969.jpg',
#  'data/imagenette/3/00970.jpg',
#  'data/imagenette/3/00971.jpg',
#  'data/imagenette/3/00972.jpg',
#  'data/imagenette/3/00973.jpg',
#  'data/imagenette/3/00974.jpg',
#  'data/imagenette/3/00975.jpg',
#  'data/imagenette/3/00976.jpg',
#  'data/imagenette/3/00977.jpg',
#  'data/imagenette/3/00978.jpg',
#  'data/imagenette/3/00979.jpg',
#  'data/imagenette/3/00980.jpg',
#  'data/imagenette/3/00981.jpg',
#  'data/imagenette/3/00982.jpg',
#  'data/imagenette/3/00983.jpg',
#  'data/imagenette/3/00984.jpg',
#  'data/imagenette/3/00985.jpg',
#  'data/imagenette/3/00986.jpg',
#  'data/imagenette/3/00987.jpg',
#  'data/imagenette/3/00988.jpg',
#  'data/imagenette/3/00989.jpg',
#  'data/imagenette/3/00990.jpg',
#  'data/imagenette/3/00991.jpg',
#  'data/imagenette/3/00992.jpg',
#  'data/imagenette/3/00993.jpg',
#  'data/imagenette/3/00994.jpg',
#  'data/imagenette/3/00995.jpg',
#  'data/imagenette/3/00996.jpg',
#  'data/imagenette/3/00997.jpg',
#  'data/imagenette/3/00998.jpg',
#  'data/imagenette/3/00999.jpg',
#  ...]

# %%
test_dl = dls.test_dl(list_of_images)

preds = learn.get_preds(dl=test_dl, with_decoded=True)
preds
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (tensor([[4.2120e-04, 3.6881e-04, 9.7402e-01,  ..., 6.3797e-03, 4.8385e-04,
#           9.4363e-04],
#          [2.4869e-03, 4.5562e-03, 9.5546e-01,  ..., 3.3204e-03, 3.0589e-03,
#           1.5761e-03],
#          [3.9638e-03, 2.9442e-02, 7.6876e-01,  ..., 8.6156e-03, 1.7566e-02,
#           1.2231e-03],
#          ...,
#          [7.2144e-04, 9.7694e-01, 8.1642e-03,  ..., 1.0540e-02, 7.9700e-04,
#           3.5924e-04],
#          [1.3826e-02, 9.3626e-01, 1.5976e-02,  ..., 5.9254e-04, 5.2087e-04,
#           2.6430e-02],
#          [1.1814e-04, 9.9943e-01, 9.4845e-05,  ..., 1.1546e-04, 4.0193e-06,
#           2.6622e-05]]),
#  None,
#  tensor([2, 2, 2,  ..., 1, 1, 1]))

# %%
preds[2]
# Out:
# tensor([2, 2, 2,  ..., 1, 1, 1])

# %%
learn.dls.vocab
# Out:
# ['English springer', 'French horn', 'cassette player', 'chain saw', 'church', 'garbage truck', 'gas pump', 'golf ball', 'parachute', 'tench']

# %%
# Convert tensor to numpy array for easier handling
pred_indices = preds[2].numpy()
# Map indices to class names using the vocabulary
pred_classes = [learn.dls.vocab[idx] for idx in pred_indices]

pred_classes
# Out:
# ['cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'French horn',
#  'golf ball',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'French horn',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'chain saw',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'French horn',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'English springer',
#  'chain saw',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'chain saw',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'church',
#  'cassette player',
#  'garbage truck',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'chain saw',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'French horn',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'French horn',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'English springer',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'English springer',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'garbage truck',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'chain saw',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'church',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'gas pump',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'garbage truck',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'cassette player',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'chain saw',
#  'tench',
#  'tench',
#  'French horn',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'cassette player',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'French horn',
#  'tench',
#  'tench',
#  'tench',
#  'cassette player',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'English springer',
#  'tench',
#  'golf ball',
#  'parachute',
#  'tench',
#  'English springer',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'English springer',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'French horn',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'French horn',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'French horn',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'gas pump',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'garbage truck',
#  'tench',
#  'tench',
#  'tench',
#  'English springer',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'French horn',
#  'tench',
#  'tench',
#  'chain saw',
#  'tench',
#  'tench',
#  'parachute',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'English springer',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'gas pump',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'English springer',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'golf ball',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'gas pump',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'tench',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'garbage truck',
#  'chain saw',
#  'chain saw',
#  'French horn',
#  'cassette player',
#  'chain saw',
#  'tench',
#  'golf ball',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'English springer',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'church',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'English springer',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'English springer',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'French horn',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'English springer',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'French horn',
#  'English springer',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'French horn',
#  'garbage truck',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'gas pump',
#  'tench',
#  'church',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'tench',
#  'garbage truck',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'cassette player',
#  'garbage truck',
#  'chain saw',
#  'chain saw',
#  'gas pump',
#  'gas pump',
#  'cassette player',
#  'chain saw',
#  'cassette player',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'tench',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  'chain saw',
#  ...]

# %%
# If you want to create a DataFrame with the predictions:
eval_df['predicted_label'] = pred_classes

# %%
eval_df
# Out:
#                          filepath       label_name  predicted_label
# 0     data/imagenette/2/00000.jpg  cassette player  cassette player
# 1     data/imagenette/2/00001.jpg  cassette player  cassette player
# 2     data/imagenette/2/00002.jpg  cassette player  cassette player
# 3     data/imagenette/2/00003.jpg  cassette player  cassette player
# 4     data/imagenette/2/00004.jpg  cassette player  cassette player
# ...                           ...              ...              ...
# 3920  data/imagenette/5/03920.jpg      French horn      French horn
# 3921  data/imagenette/5/03921.jpg      French horn      French horn
# 3922  data/imagenette/5/03922.jpg      French horn      French horn
# 3923  data/imagenette/5/03923.jpg      French horn      French horn
# 3924  data/imagenette/5/03924.jpg      French horn      French horn
#
# [3925 rows x 3 columns]

# %%
accuracy = (eval_df['label_name'] == eval_df['predicted_label']).mean()
print(f"Overall Accuracy: {accuracy:.2%}")
# Out:
# Overall Accuracy: 88.82%

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("\nDetailed Classification Report:")
print(classification_report(eval_df['label_name'], eval_df['predicted_label']))
# Out:
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
# English springer       0.94      1.00      0.97       395
#      French horn       0.92      0.90      0.91       394
#  cassette player       0.86      0.90      0.88       357
#        chain saw       0.71      0.81      0.76       386
#           church       0.91      0.94      0.92       409
#    garbage truck       0.90      0.92      0.91       389
#         gas pump       0.88      0.74      0.80       419
#        golf ball       0.97      0.92      0.94       399
#        parachute       0.96      0.82      0.88       390
#            tench       0.86      0.94      0.90       387
#
#         accuracy                           0.89      3925
#        macro avg       0.89      0.89      0.89      3925
#     weighted avg       0.89      0.89      0.89      3925

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Create confusion matrix
cm = confusion_matrix(eval_df['label_name'], eval_df['predicted_label'])

# Create a figure with larger size
plt.figure(figsize=(12, 10))

# Create heatmap
sns.heatmap(cm, 
            annot=True,  # Show numbers in cells
            fmt='d',     # Format as integer
            cmap='Blues',  # Color scheme
            xticklabels=learn.dls.vocab,
            yticklabels=learn.dls.vocab)

# Add labels
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show the plot
plt.show()

# Optional: Calculate and display normalized confusion matrix (percentages)
cm_normalized = confusion_matrix(eval_df['label_name'], eval_df['predicted_label'], normalize='true')

plt.figure(figsize=(12, 10))
sns.heatmap(cm_normalized,
            annot=True,
            fmt='.2%',  # Format as percentage
            cmap='Blues',
            xticklabels=learn.dls.vocab,
            yticklabels=learn.dls.vocab)

plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
